# %%
# !pip install pyarrow

# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
# Create example data in row-wise format
data = {'col1': [1, 2, 3, 4, 5], 'col2': ['a', 'b', 'c', 'd', 'e']}

# Convert row-wise data to a pandas DataFrame
df = pd.DataFrame(data)

# Convert pandas DataFrame to a PyArrow Table
table = pa.Table.from_pandas(df)

# Write the table to a Parquet file
pq.write_table(table, 'example.parquet')

# %%
df = pd.read_parquet("gomod.parquet")
df
# Out:
#                         repo version sub_path  \
# 0       payt0nc/fairplay-ksm  master
# 1         markelog/eclectica  v0.8.2
# 2         markelog/eclectica  v0.8.5
# 3         markelog/eclectica  v0.8.4
# 4         markelog/eclectica  v0.8.3
# ...                      ...     ...      ...
# 536671    tolik505/split-csv  v1.0.1
# 536672    tolik505/split-csv  v1.0.0
# 536673    tolik505/split-csv  v1.1.0
# 536674    tolik505/split-csv  v1.0.2
# 536675    tolik505/split-csv  v1.2.0
#
#                                                   content
# 0       module github.com/cooomma/fairplay-ksm\n\ngo 1...
# 1       module github.com/markelog/eclectica\n\ngo 1.1...
# 2       module github.com/markelog/eclectica\n\ngo 1.1...
# 3       module github.com/markelog/eclectica\n\ngo 1.1...
# 4       module github.com/markelog/eclectica\n\ngo 1.1...
# ...                                                   ...
# 536671  module github.com/tolik505/split-csv\n\ngo 1.1...
# 536672  module github.com/tolik505/split-csv\n\ngo 1.1...
# 536673  module github.com/tolik505/split-csv\n\ngo 1.1...
# 536674  module github.com/tolik505/split-csv\n\ngo 1.1...
# 536675  module github.com/tolik505/split-csv\n\ngo 1.1...
#
# [536676 rows x 4 columns]
